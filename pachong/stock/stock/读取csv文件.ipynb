# %%
import pandas as pd
import re

# %%
df = pd.read_csv('baidustockinfo.csv',encoding = 'gbk')

# %%
df[df['代码']==300033].T
# Out:
#             695
# 股票名称        同花顺
# 代码       300033
# 今开           38
# 最高        38.85
# 最低        37.92
# 成交量      2.85万手
# 涨停           42
# 内盘       1.44万手
# 成交额       1.09亿
# 委比       14.94%
# 流通市值    100.83亿
# 市盈率       68.23
# 每股收益       0.14
# 总股本       5.38亿
# 昨收        38.18
# 换手率       1.08%
# 跌停          non
# 外盘       1.41万手
# 振幅        2.44%
# 量比         0.52
# 总市值     205.63亿
# 高净率        7.49
# 每股净资产      5.11
# 流通股本      2.64亿
